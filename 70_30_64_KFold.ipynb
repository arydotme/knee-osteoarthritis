# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model

# %%
sdir = '/content/drive/MyDrive/XrayKneeOsteoarthritis'
image_size = (224, 224)
batch_size = 64
k_folds = 5

# %%
filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths labels
# 0  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 1  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 2  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 3  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 4  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# labels
# 0    3798
# 2    2545
# 4    1790
# 1    1749
# 3    1281
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(df, test_size=0.3, stratify=df['labels'], random_state=42)

print(train_df['labels'].value_counts())
print(test_df['labels'].value_counts())
# Out:
# labels
# 0    2659
# 2    1781
# 4    1253
# 1    1224
# 3     897
# Name: count, dtype: int64
# labels
# 0    1139
# 2     764
# 4     537
# 1     525
# 3     384
# Name: count, dtype: int64

# %%
datagen = ImageDataGenerator(
  rescale=1.0/255,
  horizontal_flip = True,
  )

valid_generator = ImageDataGenerator(
    rescale = 1./255
)

test_generator = ImageDataGenerator(
    rescale = 1./255
)

test_gen = test_generator.flow_from_dataframe(
    test_df, x_col='filepaths', y_col='labels', target_size=image_size,
    batch_size=batch_size, class_mode='categorical', shuffle = True
)

print("Preprocessing dataset selesai.")
# Out:
# Found 3349 validated image filenames belonging to 5 classes.
# Preprocessing dataset selesai.

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(10, 10))
    length=len(labels)
    if length<15:   #show maximum of 25 images
        r=length
    else:
        r=15
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=12)
        plt.axis('off')
    plt.show()

show_image_samples(test_gen)

# %%
kf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

def create_model():
    base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze semua layer kecuali 4 terakhir
    for layer in base_model.layers[:-8]:
        layer.trainable = False
    for layer in base_model.layers[-8:]:
        layer.trainable = True

    x = base_model.output

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = GlobalAveragePooling2D()(x)

    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)

    predictions = Dense(5, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

fold_accuracies = []
histories = []
fold = 1

for train_index, val_index in kf.split(train_df, train_df['labels']):
    print(f'\nTraining Fold {fold}...')

    fold_train_df = train_df.iloc[train_index].reset_index(drop = True)
    fold_valid_df = train_df.iloc[val_index].reset_index(drop = True)

    classes = np.unique(fold_train_df['labels'])
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=fold_train_df['labels'])
    class_weight_dict = dict(zip(classes, class_weights))
    print(f"Class weights (Fold {fold}):", class_weight_dict)

    train_gen = datagen.flow_from_dataframe(
        fold_train_df,
        x_col='filepaths',
        y_col='labels',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    val_gen = valid_generator.flow_from_dataframe(
        fold_valid_df,
        x_col='filepaths',
        y_col='labels',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )

    model = create_model()

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=20,
        callbacks=[early_stopping, reduce_lr]
    )

    histories.append(history)

    scores = model.evaluate(val_gen, verbose=0)
    print(f"Fold {fold} - Loss: {scores[0]} - Accuracy: {scores[1]*100:.2f}%")

    fold_accuracies.append(scores[1] * 100)
    fold += 1

print('=================================')
print(f'Average accuracy over {k_folds} folds: {np.mean(fold_accuracies):.2f}% (+/- {np.std(fold_accuracies):.2f})')
print('=================================')
# Out:
# Training Fold 1...
# Class weights (Fold 1): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7436541143654114), '4': np.float64(1.2464606181455633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2731s 28s/step - accuracy: 0.3192 - loss: 1.6186 - val_accuracy: 0.4702 - val_loss: 1.3194 - learning_rate: 1.0000e-04
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 572ms/step - accuracy: 0.5043 - loss: 1.1532 - val_accuracy: 0.4728 - val_loss: 1.2063 - learning_rate: 1.0000e-04
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 567ms/step - accuracy: 0.5460 - loss: 1.0475 - val_accuracy: 0.3257 - val_loss: 1.5430 - learning_rate: 1.0000e-04
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 579ms/step - accuracy: 0.5900 - loss: 0.9335 - val_accuracy: 0.5701 - val_loss: 1.0338 - learning_rate: 1.0000e-04
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 81s 569ms/step - accuracy: 0.6178 - loss: 0.9007 - val_accuracy: 0.6072 - val_loss: 0.9352 - learning_rate: 1.0000e-04
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.6426 - loss: 0.8278 - val_accuracy: 0.4408 - val_loss: 1.6594 - learning_rate: 1.0000e-04
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 571ms/step - accuracy: 0.6746 - loss: 0.7920 - val_accuracy: 0.6443 - val_loss: 0.8256 - learning_rate: 1.0000e-04
# Epoch 8/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 550ms/step - accuracy: 0.6733 - loss: 0.7682 - val_accuracy: 0.5809 - val_loss: 1.1040 - learning_rate: 1.0000e-04
# Epoch 9/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.6642 - loss: 0.7831 - val_accuracy: 0.6628 - val_loss: 0.8531 - learning_rate: 1.0000e-04
# Epoch 10/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7104 - loss: 0.6793 - val_accuracy: 0.6827 - val_loss: 0.7707 - learning_rate: 2.0000e-05
# Epoch 11/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.7456 - loss: 0.6177 - val_accuracy: 0.6948 - val_loss: 0.7432 - learning_rate: 2.0000e-05
# Epoch 12/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 555ms/step - accuracy: 0.7277 - loss: 0.6513 - val_accuracy: 0.6948 - val_loss: 0.7597 - learning_rate: 2.0000e-05
# Epoch 13/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 555ms/step - accuracy: 0.7413 - loss: 0.6161 - val_accuracy: 0.6667 - val_loss: 0.8412 - learning_rate: 2.0000e-05
# Epoch 14/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 570ms/step - accuracy: 0.7474 - loss: 0.6091 - val_accuracy: 0.6999 - val_loss: 0.7312 - learning_rate: 4.0000e-06
# Epoch 15/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7536 - loss: 0.6024 - val_accuracy: 0.6980 - val_loss: 0.7301 - learning_rate: 4.0000e-06
# Epoch 16/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 547ms/step - accuracy: 0.7610 - loss: 0.5722 - val_accuracy: 0.6961 - val_loss: 0.7440 - learning_rate: 4.0000e-06
# Epoch 17/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 53s 543ms/step - accuracy: 0.7636 - loss: 0.5783 - val_accuracy: 0.6916 - val_loss: 0.7298 - learning_rate: 4.0000e-06
# Epoch 18/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 569ms/step - accuracy: 0.7569 - loss: 0.5814 - val_accuracy: 0.6833 - val_loss: 0.8054 - learning_rate: 4.0000e-06
# Epoch 19/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 81s 562ms/step - accuracy: 0.7634 - loss: 0.5688 - val_accuracy: 0.6903 - val_loss: 0.7408 - learning_rate: 4.0000e-06
# Epoch 20/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 547ms/step - accuracy: 0.7768 - loss: 0.5427 - val_accuracy: 0.7012 - val_loss: 0.7371 - learning_rate: 8.0000e-07
# Fold 1 - Loss: 0.7297650575637817 - Accuracy: 69.16%
#
# Training Fold 2...
# Class weights (Fold 2): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7436541143654114), '4': np.float64(1.2464606181455633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 77s 700ms/step - accuracy: 0.3377 - loss: 1.6057 - val_accuracy: 0.1606 - val_loss: 2.1123 - learning_rate: 1.0000e-04
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 553ms/step - accuracy: 0.4918 - loss: 1.1859 - val_accuracy: 0.5278 - val_loss: 1.0546 - learning_rate: 1.0000e-04
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 569ms/step - accuracy: 0.5606 - loss: 1.0154 - val_accuracy: 0.5701 - val_loss: 0.9893 - learning_rate: 1.0000e-04
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.6094 - loss: 0.9340 - val_accuracy: 0.6296 - val_loss: 0.8409 - learning_rate: 1.0000e-04
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 552ms/step - accuracy: 0.6378 - loss: 0.8699 - val_accuracy: 0.6462 - val_loss: 0.8386 - learning_rate: 1.0000e-04
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 570ms/step - accuracy: 0.6635 - loss: 0.7915 - val_accuracy: 0.6475 - val_loss: 0.8659 - learning_rate: 1.0000e-04
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 59s 595ms/step - accuracy: 0.6785 - loss: 0.7768 - val_accuracy: 0.6142 - val_loss: 0.9006 - learning_rate: 1.0000e-04
# Epoch 8/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 576ms/step - accuracy: 0.6953 - loss: 0.7390 - val_accuracy: 0.6545 - val_loss: 0.8198 - learning_rate: 2.0000e-05
# Epoch 9/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 81s 569ms/step - accuracy: 0.7166 - loss: 0.6870 - val_accuracy: 0.6807 - val_loss: 0.7356 - learning_rate: 2.0000e-05
# Epoch 10/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 569ms/step - accuracy: 0.7309 - loss: 0.6533 - val_accuracy: 0.6328 - val_loss: 0.9078 - learning_rate: 2.0000e-05
# Epoch 11/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 576ms/step - accuracy: 0.7168 - loss: 0.6610 - val_accuracy: 0.6775 - val_loss: 0.7620 - learning_rate: 2.0000e-05
# Epoch 12/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 573ms/step - accuracy: 0.7282 - loss: 0.6419 - val_accuracy: 0.7159 - val_loss: 0.6723 - learning_rate: 4.0000e-06
# Epoch 13/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7432 - loss: 0.6104 - val_accuracy: 0.7102 - val_loss: 0.6739 - learning_rate: 4.0000e-06
# Epoch 14/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 572ms/step - accuracy: 0.7368 - loss: 0.6227 - val_accuracy: 0.7140 - val_loss: 0.6683 - learning_rate: 4.0000e-06
# Epoch 15/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 557ms/step - accuracy: 0.7500 - loss: 0.6009 - val_accuracy: 0.7051 - val_loss: 0.6700 - learning_rate: 4.0000e-06
# Epoch 16/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 579ms/step - accuracy: 0.7414 - loss: 0.6166 - val_accuracy: 0.7083 - val_loss: 0.6669 - learning_rate: 4.0000e-06
# Epoch 17/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 566ms/step - accuracy: 0.7548 - loss: 0.5898 - val_accuracy: 0.7166 - val_loss: 0.6655 - learning_rate: 4.0000e-06
# Epoch 18/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 557ms/step - accuracy: 0.7649 - loss: 0.5784 - val_accuracy: 0.7089 - val_loss: 0.6617 - learning_rate: 4.0000e-06
# Epoch 19/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 566ms/step - accuracy: 0.7629 - loss: 0.5799 - val_accuracy: 0.7025 - val_loss: 0.7107 - learning_rate: 4.0000e-06
# Epoch 20/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 573ms/step - accuracy: 0.7613 - loss: 0.5746 - val_accuracy: 0.7147 - val_loss: 0.6727 - learning_rate: 4.0000e-06
# Fold 2 - Loss: 0.661704957485199 - Accuracy: 70.89%
#
# Training Fold 3...
# Class weights (Fold 3): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7412256267409472), '4': np.float64(1.2477045908183633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 70s 624ms/step - accuracy: 0.3160 - loss: 1.6085 - val_accuracy: 0.2482 - val_loss: 1.6430 - learning_rate: 1.0000e-04
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 567ms/step - accuracy: 0.4863 - loss: 1.2087 - val_accuracy: 0.5790 - val_loss: 1.0252 - learning_rate: 1.0000e-04
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 553ms/step - accuracy: 0.5399 - loss: 1.0658 - val_accuracy: 0.3455 - val_loss: 1.4058 - learning_rate: 1.0000e-04
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.6045 - loss: 0.9188 - val_accuracy: 0.5880 - val_loss: 1.0192 - learning_rate: 1.0000e-04
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.6389 - loss: 0.8484 - val_accuracy: 0.6200 - val_loss: 0.9199 - learning_rate: 1.0000e-04
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.6505 - loss: 0.8428 - val_accuracy: 0.6072 - val_loss: 0.9350 - learning_rate: 1.0000e-04
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 555ms/step - accuracy: 0.6625 - loss: 0.7956 - val_accuracy: 0.6456 - val_loss: 0.8903 - learning_rate: 1.0000e-04
# Epoch 8/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.6792 - loss: 0.7434 - val_accuracy: 0.6276 - val_loss: 0.8705 - learning_rate: 1.0000e-04
# Epoch 9/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 570ms/step - accuracy: 0.6940 - loss: 0.7236 - val_accuracy: 0.6999 - val_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 10/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 551ms/step - accuracy: 0.7052 - loss: 0.7065 - val_accuracy: 0.4024 - val_loss: 2.1316 - learning_rate: 1.0000e-04
# Epoch 11/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 554ms/step - accuracy: 0.7050 - loss: 0.6911 - val_accuracy: 0.6532 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 12/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 572ms/step - accuracy: 0.7262 - loss: 0.6462 - val_accuracy: 0.6807 - val_loss: 0.7974 - learning_rate: 2.0000e-05
# Fold 3 - Loss: 0.7301236391067505 - Accuracy: 69.99%
#
# Training Fold 4...
# Class weights (Fold 4): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7412256267409472), '4': np.float64(1.2477045908183633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 70s 621ms/step - accuracy: 0.3133 - loss: 1.6296 - val_accuracy: 0.4773 - val_loss: 1.2866 - learning_rate: 1.0000e-04
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 554ms/step - accuracy: 0.4889 - loss: 1.1818 - val_accuracy: 0.4613 - val_loss: 1.1916 - learning_rate: 1.0000e-04
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 554ms/step - accuracy: 0.5427 - loss: 1.0518 - val_accuracy: 0.5752 - val_loss: 0.9812 - learning_rate: 1.0000e-04
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.5770 - loss: 0.9800 - val_accuracy: 0.5656 - val_loss: 0.9765 - learning_rate: 1.0000e-04
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 550ms/step - accuracy: 0.6147 - loss: 0.8927 - val_accuracy: 0.4415 - val_loss: 1.8114 - learning_rate: 1.0000e-04
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 561ms/step - accuracy: 0.6398 - loss: 0.8545 - val_accuracy: 0.3135 - val_loss: 1.7025 - learning_rate: 1.0000e-04
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 554ms/step - accuracy: 0.6715 - loss: 0.7917 - val_accuracy: 0.6814 - val_loss: 0.7567 - learning_rate: 2.0000e-05
# Epoch 8/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.6815 - loss: 0.7552 - val_accuracy: 0.6788 - val_loss: 0.7652 - learning_rate: 2.0000e-05
# Epoch 9/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 550ms/step - accuracy: 0.7065 - loss: 0.7202 - val_accuracy: 0.6807 - val_loss: 0.7650 - learning_rate: 2.0000e-05
# Epoch 10/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 552ms/step - accuracy: 0.7236 - loss: 0.6748 - val_accuracy: 0.7038 - val_loss: 0.7042 - learning_rate: 4.0000e-06
# Epoch 11/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 562ms/step - accuracy: 0.7102 - loss: 0.6877 - val_accuracy: 0.7083 - val_loss: 0.7051 - learning_rate: 4.0000e-06
# Epoch 12/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 558ms/step - accuracy: 0.7215 - loss: 0.6697 - val_accuracy: 0.7121 - val_loss: 0.6762 - learning_rate: 4.0000e-06
# Epoch 13/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 548ms/step - accuracy: 0.7283 - loss: 0.6641 - val_accuracy: 0.7012 - val_loss: 0.7180 - learning_rate: 4.0000e-06
# Epoch 14/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.7228 - loss: 0.6744 - val_accuracy: 0.7185 - val_loss: 0.6793 - learning_rate: 4.0000e-06
# Epoch 15/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 567ms/step - accuracy: 0.7256 - loss: 0.6654 - val_accuracy: 0.7159 - val_loss: 0.6759 - learning_rate: 8.0000e-07
# Epoch 16/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 57s 576ms/step - accuracy: 0.7130 - loss: 0.6851 - val_accuracy: 0.7204 - val_loss: 0.6702 - learning_rate: 8.0000e-07
# Epoch 17/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.7289 - loss: 0.6595 - val_accuracy: 0.7179 - val_loss: 0.6696 - learning_rate: 8.0000e-07
# Epoch 18/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 557ms/step - accuracy: 0.7223 - loss: 0.6552 - val_accuracy: 0.7191 - val_loss: 0.6718 - learning_rate: 8.0000e-07
# Epoch 19/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 555ms/step - accuracy: 0.7273 - loss: 0.6490 - val_accuracy: 0.7210 - val_loss: 0.6668 - learning_rate: 8.0000e-07
# Epoch 20/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 565ms/step - accuracy: 0.7243 - loss: 0.6608 - val_accuracy: 0.7140 - val_loss: 0.6759 - learning_rate: 8.0000e-07
# Fold 4 - Loss: 0.6667898297309875 - Accuracy: 72.10%
#
# Training Fold 5...
# Class weights (Fold 5): {'0': np.float64(0.587593984962406), '1': np.float64(1.2759183673469388), '2': np.float64(0.8780898876404495), '3': np.float64(1.7415041782729805), '4': np.float64(1.2479041916167664)}
# Found 6252 validated image filenames belonging to 5 classes.
# Found 1562 validated image filenames belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 97s 906ms/step - accuracy: 0.3199 - loss: 1.6118 - val_accuracy: 0.4878 - val_loss: 1.2295 - learning_rate: 1.0000e-04
# Epoch 2/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 547ms/step - accuracy: 0.5285 - loss: 1.1249 - val_accuracy: 0.5410 - val_loss: 1.0881 - learning_rate: 1.0000e-04
# Epoch 3/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 553ms/step - accuracy: 0.5820 - loss: 0.9908 - val_accuracy: 0.5755 - val_loss: 0.9708 - learning_rate: 1.0000e-04
# Epoch 4/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 574ms/step - accuracy: 0.6280 - loss: 0.8985 - val_accuracy: 0.6261 - val_loss: 0.8870 - learning_rate: 1.0000e-04
# Epoch 5/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 556ms/step - accuracy: 0.6508 - loss: 0.8389 - val_accuracy: 0.6248 - val_loss: 0.8967 - learning_rate: 1.0000e-04
# Epoch 6/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 548ms/step - accuracy: 0.6796 - loss: 0.7743 - val_accuracy: 0.5512 - val_loss: 1.2954 - learning_rate: 1.0000e-04
# Epoch 7/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 554ms/step - accuracy: 0.6855 - loss: 0.7460 - val_accuracy: 0.7023 - val_loss: 0.7002 - learning_rate: 2.0000e-05
# Epoch 8/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.7108 - loss: 0.6900 - val_accuracy: 0.6972 - val_loss: 0.7070 - learning_rate: 2.0000e-05
# Epoch 9/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 561ms/step - accuracy: 0.7314 - loss: 0.6654 - val_accuracy: 0.7074 - val_loss: 0.6983 - learning_rate: 2.0000e-05
# Epoch 10/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 561ms/step - accuracy: 0.7237 - loss: 0.6666 - val_accuracy: 0.7010 - val_loss: 0.7046 - learning_rate: 2.0000e-05
# Epoch 11/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 564ms/step - accuracy: 0.7406 - loss: 0.6289 - val_accuracy: 0.6940 - val_loss: 0.7210 - learning_rate: 2.0000e-05
# Epoch 12/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 560ms/step - accuracy: 0.7478 - loss: 0.6144 - val_accuracy: 0.7113 - val_loss: 0.6640 - learning_rate: 4.0000e-06
# Epoch 13/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 550ms/step - accuracy: 0.7469 - loss: 0.6072 - val_accuracy: 0.7157 - val_loss: 0.6682 - learning_rate: 4.0000e-06
# Epoch 14/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7599 - loss: 0.5941 - val_accuracy: 0.7254 - val_loss: 0.6606 - learning_rate: 4.0000e-06
# Epoch 15/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 562ms/step - accuracy: 0.7679 - loss: 0.5781 - val_accuracy: 0.7093 - val_loss: 0.6857 - learning_rate: 4.0000e-06
# Epoch 16/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 56s 564ms/step - accuracy: 0.7628 - loss: 0.5911 - val_accuracy: 0.7202 - val_loss: 0.6589 - learning_rate: 4.0000e-06
# Epoch 17/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 55s 563ms/step - accuracy: 0.7612 - loss: 0.5910 - val_accuracy: 0.7202 - val_loss: 0.6603 - learning_rate: 4.0000e-06
# Epoch 18/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 552ms/step - accuracy: 0.7727 - loss: 0.5601 - val_accuracy: 0.7177 - val_loss: 0.6624 - learning_rate: 4.0000e-06
# Epoch 19/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 54s 548ms/step - accuracy: 0.7689 - loss: 0.5628 - val_accuracy: 0.7177 - val_loss: 0.6579 - learning_rate: 8.0000e-07
# Epoch 20/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 58s 586ms/step - accuracy: 0.7690 - loss: 0.5585 - val_accuracy: 0.7215 - val_loss: 0.6594 - learning_rate: 8.0000e-07
# Fold 5 - Loss: 0.6579124927520752 - Accuracy: 71.77%
# =================================
# Average accuracy over 5 folds: 70.78% (+/- 1.09)
# =================================

# %%
for i, history in enumerate(histories, start=1):
    plt.figure(figsize=(12, 5))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'Fold {i} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'Fold {i} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.suptitle(f'Performance for Fold {i}', fontsize=16)
    plt.tight_layout()
    plt.show()  # tampilkan plot fold i

print("Semua plot selesai!")
# Out:
# Semua plot selesai!

# %%
y_true = []
y_pred = []
class_labels = list(test_gen.class_indices.keys())

for _ in range(len(test_gen)):
    x_batch, y_batch = next(test_gen)
    y_true.extend(np.argmax(y_batch, axis=1))  # Label asli
    y_pred.extend(np.argmax(model.predict(x_batch), axis=1))  # Prediksi model

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.89      0.79      1132
#            1       0.36      0.15      0.21       523
#            2       0.66      0.71      0.68       770
#            3       0.86      0.77      0.81       389
#            4       0.97      0.99      0.98       535
#
#     accuracy                           0.73      3349
#    macro avg       0.71      0.70      0.70      3349
# weighted avg       0.70      0.73      0.71      3349

# %%
model.save('/content/drive/MyDrive/my_model_70_30_64.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/MyDrive/CNN_VGG16_KneeOsteoarthritis.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
