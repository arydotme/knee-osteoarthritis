# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model

# %%
sdir = '/content/drive/MyDrive/XrayKneeOsteoarthritis'
image_size = (224, 224)
batch_size = 16
k_folds = 5

# %%
filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths labels
# 0  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 1  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 2  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 3  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# 4  /content/drive/MyDrive/XrayKneeOsteoarthritis/...      0
# labels
# 0    3798
# 2    2545
# 4    1790
# 1    1749
# 3    1281
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(df, test_size=0.3, stratify=df['labels'], random_state=42)

print(train_df['labels'].value_counts())
print(test_df['labels'].value_counts())
# Out:
# labels
# 0    2659
# 2    1781
# 4    1253
# 1    1224
# 3     897
# Name: count, dtype: int64
# labels
# 0    1139
# 2     764
# 4     537
# 1     525
# 3     384
# Name: count, dtype: int64

# %%
datagen = ImageDataGenerator(
  rescale=1.0/255,
  horizontal_flip = True,
  )

valid_generator = ImageDataGenerator(
    rescale = 1./255
)

test_generator = ImageDataGenerator(
    rescale = 1./255
)

test_gen = test_generator.flow_from_dataframe(
    test_df, x_col='filepaths', y_col='labels', target_size=image_size,
    batch_size=batch_size, class_mode='categorical', shuffle = True
)

print("Preprocessing dataset selesai.")
# Out:
# Found 3349 validated image filenames belonging to 5 classes.
# Preprocessing dataset selesai.

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(10, 10))
    length=len(labels)
    if length<15:   #show maximum of 25 images
        r=length
    else:
        r=15
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=12)
        plt.axis('off')
    plt.show()

show_image_samples(test_gen)

# %%
kf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

def create_model():
    base_model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    # Freeze semua layer kecuali 4 terakhir
    for layer in base_model.layers[:-8]:
        layer.trainable = False
    for layer in base_model.layers[-8:]:
        layer.trainable = True

    x = base_model.output

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)

    x = GlobalAveragePooling2D()(x)

    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)

    predictions = Dense(5, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4, weight_decay=0.001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

fold_accuracies = []
histories = []
fold = 1

for train_index, val_index in kf.split(train_df, train_df['labels']):
    print(f'\nTraining Fold {fold}...')

    fold_train_df = train_df.iloc[train_index].reset_index(drop = True)
    fold_valid_df = train_df.iloc[val_index].reset_index(drop = True)

    classes = np.unique(fold_train_df['labels'])
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=fold_train_df['labels'])
    class_weight_dict = dict(zip(classes, class_weights))
    print(f"Class weights (Fold {fold}):", class_weight_dict)

    train_gen = datagen.flow_from_dataframe(
        fold_train_df,
        x_col='filepaths',
        y_col='labels',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True
    )

    val_gen = valid_generator.flow_from_dataframe(
        fold_valid_df,
        x_col='filepaths',
        y_col='labels',
        target_size=image_size,
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False
    )

    model = create_model()

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)

    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=20,
        callbacks=[early_stopping, reduce_lr]
    )

    histories.append(history)

    scores = model.evaluate(val_gen, verbose=0)
    print(f"Fold {fold} - Loss: {scores[0]} - Accuracy: {scores[1]*100:.2f}%")

    fold_accuracies.append(scores[1] * 100)
    fold += 1

print('=================================')
print(f'Average accuracy over {k_folds} folds: {np.mean(fold_accuracies):.2f}% (+/- {np.std(fold_accuracies):.2f})')
print('=================================')
# Out:
# Training Fold 1...
# Class weights (Fold 1): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7436541143654114), '4': np.float64(1.2464606181455633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3108s 8s/step - accuracy: 0.3210 - loss: 1.6048 - val_accuracy: 0.4792 - val_loss: 1.2642 - learning_rate: 1.0000e-04
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 73s 187ms/step - accuracy: 0.4838 - loss: 1.1855 - val_accuracy: 0.2732 - val_loss: 1.5777 - learning_rate: 1.0000e-04
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.5472 - loss: 1.0518 - val_accuracy: 0.6148 - val_loss: 0.8876 - learning_rate: 1.0000e-04
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6119 - loss: 0.9088 - val_accuracy: 0.5470 - val_loss: 1.1863 - learning_rate: 1.0000e-04
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6432 - loss: 0.8513 - val_accuracy: 0.5669 - val_loss: 0.9779 - learning_rate: 1.0000e-04
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6742 - loss: 0.7952 - val_accuracy: 0.6884 - val_loss: 0.7344 - learning_rate: 2.0000e-05
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6884 - loss: 0.7454 - val_accuracy: 0.6935 - val_loss: 0.7251 - learning_rate: 2.0000e-05
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6916 - loss: 0.7469 - val_accuracy: 0.7083 - val_loss: 0.6929 - learning_rate: 2.0000e-05
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7063 - loss: 0.7142 - val_accuracy: 0.7051 - val_loss: 0.7050 - learning_rate: 2.0000e-05
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7049 - loss: 0.7143 - val_accuracy: 0.6993 - val_loss: 0.7205 - learning_rate: 2.0000e-05
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 83s 186ms/step - accuracy: 0.7050 - loss: 0.6901 - val_accuracy: 0.7102 - val_loss: 0.6816 - learning_rate: 4.0000e-06
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7221 - loss: 0.6744 - val_accuracy: 0.7223 - val_loss: 0.6657 - learning_rate: 4.0000e-06
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7230 - loss: 0.6571 - val_accuracy: 0.7140 - val_loss: 0.6639 - learning_rate: 4.0000e-06
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7277 - loss: 0.6587 - val_accuracy: 0.7242 - val_loss: 0.6628 - learning_rate: 4.0000e-06
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 73s 187ms/step - accuracy: 0.7210 - loss: 0.6660 - val_accuracy: 0.7095 - val_loss: 0.6726 - learning_rate: 4.0000e-06
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7408 - loss: 0.6197 - val_accuracy: 0.7210 - val_loss: 0.6594 - learning_rate: 4.0000e-06
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7392 - loss: 0.6254 - val_accuracy: 0.7159 - val_loss: 0.6575 - learning_rate: 4.0000e-06
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7390 - loss: 0.6357 - val_accuracy: 0.7274 - val_loss: 0.6597 - learning_rate: 4.0000e-06
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7358 - loss: 0.6369 - val_accuracy: 0.7242 - val_loss: 0.6518 - learning_rate: 4.0000e-06
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7396 - loss: 0.6239 - val_accuracy: 0.7294 - val_loss: 0.6544 - learning_rate: 4.0000e-06
# Fold 1 - Loss: 0.6517975330352783 - Accuracy: 72.42%
#
# Training Fold 2...
# Class weights (Fold 2): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7436541143654114), '4': np.float64(1.2464606181455633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 84s 194ms/step - accuracy: 0.3624 - loss: 1.5193 - val_accuracy: 0.1817 - val_loss: 2.4152 - learning_rate: 1.0000e-04
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 71s 180ms/step - accuracy: 0.5245 - loss: 1.1147 - val_accuracy: 0.5477 - val_loss: 1.0716 - learning_rate: 1.0000e-04
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 71s 182ms/step - accuracy: 0.5915 - loss: 0.9799 - val_accuracy: 0.4786 - val_loss: 1.6909 - learning_rate: 1.0000e-04
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 71s 182ms/step - accuracy: 0.6300 - loss: 0.8891 - val_accuracy: 0.5227 - val_loss: 1.0202 - learning_rate: 1.0000e-04
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 71s 182ms/step - accuracy: 0.6472 - loss: 0.8378 - val_accuracy: 0.5976 - val_loss: 0.9782 - learning_rate: 1.0000e-04
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 71s 182ms/step - accuracy: 0.6619 - loss: 0.8116 - val_accuracy: 0.6123 - val_loss: 0.8985 - learning_rate: 1.0000e-04
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 83s 184ms/step - accuracy: 0.6792 - loss: 0.7728 - val_accuracy: 0.6705 - val_loss: 0.7779 - learning_rate: 1.0000e-04
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 183ms/step - accuracy: 0.6931 - loss: 0.7348 - val_accuracy: 0.6833 - val_loss: 0.7522 - learning_rate: 1.0000e-04
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6921 - loss: 0.7400 - val_accuracy: 0.5752 - val_loss: 1.1107 - learning_rate: 1.0000e-04
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7027 - loss: 0.7114 - val_accuracy: 0.7006 - val_loss: 0.7340 - learning_rate: 1.0000e-04
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 183ms/step - accuracy: 0.7199 - loss: 0.6914 - val_accuracy: 0.6667 - val_loss: 0.7949 - learning_rate: 1.0000e-04
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7136 - loss: 0.6836 - val_accuracy: 0.6935 - val_loss: 0.7266 - learning_rate: 1.0000e-04
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7298 - loss: 0.6513 - val_accuracy: 0.7070 - val_loss: 0.7214 - learning_rate: 1.0000e-04
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7299 - loss: 0.6547 - val_accuracy: 0.6583 - val_loss: 0.8451 - learning_rate: 1.0000e-04
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7385 - loss: 0.6340 - val_accuracy: 0.6820 - val_loss: 0.7566 - learning_rate: 1.0000e-04
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7626 - loss: 0.5788 - val_accuracy: 0.7121 - val_loss: 0.6630 - learning_rate: 2.0000e-05
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7763 - loss: 0.5213 - val_accuracy: 0.7127 - val_loss: 0.6737 - learning_rate: 2.0000e-05
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7900 - loss: 0.5052 - val_accuracy: 0.7031 - val_loss: 0.7120 - learning_rate: 2.0000e-05
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7996 - loss: 0.4829 - val_accuracy: 0.7159 - val_loss: 0.6690 - learning_rate: 4.0000e-06
# Fold 2 - Loss: 0.6629646420478821 - Accuracy: 71.21%
#
# Training Fold 3...
# Class weights (Fold 3): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7412256267409472), '4': np.float64(1.2477045908183633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 198ms/step - accuracy: 0.3418 - loss: 1.5784 - val_accuracy: 0.4069 - val_loss: 1.2531 - learning_rate: 1.0000e-04
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.4826 - loss: 1.1982 - val_accuracy: 0.3679 - val_loss: 1.4064 - learning_rate: 1.0000e-04
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.5583 - loss: 1.0220 - val_accuracy: 0.5374 - val_loss: 1.1151 - learning_rate: 1.0000e-04
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 183ms/step - accuracy: 0.5644 - loss: 1.0085 - val_accuracy: 0.5720 - val_loss: 1.0365 - learning_rate: 1.0000e-04
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6221 - loss: 0.9042 - val_accuracy: 0.5406 - val_loss: 1.1335 - learning_rate: 1.0000e-04
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 82s 185ms/step - accuracy: 0.6362 - loss: 0.8581 - val_accuracy: 0.5861 - val_loss: 1.0357 - learning_rate: 1.0000e-04
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6552 - loss: 0.8220 - val_accuracy: 0.5617 - val_loss: 0.9905 - learning_rate: 1.0000e-04
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 82s 185ms/step - accuracy: 0.6614 - loss: 0.8144 - val_accuracy: 0.6244 - val_loss: 0.8861 - learning_rate: 1.0000e-04
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6807 - loss: 0.7807 - val_accuracy: 0.6398 - val_loss: 0.8773 - learning_rate: 1.0000e-04
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6926 - loss: 0.7561 - val_accuracy: 0.6756 - val_loss: 0.8022 - learning_rate: 1.0000e-04
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6915 - loss: 0.7359 - val_accuracy: 0.6679 - val_loss: 0.8178 - learning_rate: 1.0000e-04
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6952 - loss: 0.7235 - val_accuracy: 0.5867 - val_loss: 1.0313 - learning_rate: 1.0000e-04
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7209 - loss: 0.6633 - val_accuracy: 0.7255 - val_loss: 0.6918 - learning_rate: 2.0000e-05
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7424 - loss: 0.6182 - val_accuracy: 0.7191 - val_loss: 0.6859 - learning_rate: 2.0000e-05
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 183ms/step - accuracy: 0.7412 - loss: 0.6151 - val_accuracy: 0.7236 - val_loss: 0.6860 - learning_rate: 2.0000e-05
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7544 - loss: 0.5881 - val_accuracy: 0.7057 - val_loss: 0.6964 - learning_rate: 2.0000e-05
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 82s 185ms/step - accuracy: 0.7475 - loss: 0.5980 - val_accuracy: 0.7166 - val_loss: 0.6754 - learning_rate: 4.0000e-06
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7561 - loss: 0.5740 - val_accuracy: 0.7159 - val_loss: 0.6699 - learning_rate: 4.0000e-06
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7637 - loss: 0.5608 - val_accuracy: 0.7230 - val_loss: 0.6718 - learning_rate: 4.0000e-06
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7654 - loss: 0.5531 - val_accuracy: 0.7255 - val_loss: 0.6698 - learning_rate: 4.0000e-06
# Fold 3 - Loss: 0.6698148846626282 - Accuracy: 72.55%
#
# Training Fold 4...
# Class weights (Fold 4): {'0': np.float64(0.5877762106252938), '1': np.float64(1.277017364657814), '2': np.float64(0.8773333333333333), '3': np.float64(1.7412256267409472), '4': np.float64(1.2477045908183633)}
# Found 6251 validated image filenames belonging to 5 classes.
# Found 1563 validated image filenames belonging to 5 classes.
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 86s 199ms/step - accuracy: 0.3390 - loss: 1.5682 - val_accuracy: 0.5106 - val_loss: 1.1555 - learning_rate: 1.0000e-04
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 73s 185ms/step - accuracy: 0.5133 - loss: 1.1487 - val_accuracy: 0.4127 - val_loss: 1.6975 - learning_rate: 1.0000e-04
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.5680 - loss: 0.9967 - val_accuracy: 0.5950 - val_loss: 0.9950 - learning_rate: 1.0000e-04
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6201 - loss: 0.9117 - val_accuracy: 0.6539 - val_loss: 0.8095 - learning_rate: 1.0000e-04
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6356 - loss: 0.8690 - val_accuracy: 0.6743 - val_loss: 0.7546 - learning_rate: 1.0000e-04
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6619 - loss: 0.8096 - val_accuracy: 0.6110 - val_loss: 1.1513 - learning_rate: 1.0000e-04
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6874 - loss: 0.7557 - val_accuracy: 0.6782 - val_loss: 0.7512 - learning_rate: 1.0000e-04
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6847 - loss: 0.7596 - val_accuracy: 0.6961 - val_loss: 0.7211 - learning_rate: 1.0000e-04
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6899 - loss: 0.7433 - val_accuracy: 0.5630 - val_loss: 1.0450 - learning_rate: 1.0000e-04
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6975 - loss: 0.7185 - val_accuracy: 0.6775 - val_loss: 0.8052 - learning_rate: 1.0000e-04
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7239 - loss: 0.6758 - val_accuracy: 0.7121 - val_loss: 0.6758 - learning_rate: 2.0000e-05
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7467 - loss: 0.6126 - val_accuracy: 0.7089 - val_loss: 0.6737 - learning_rate: 2.0000e-05
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7530 - loss: 0.5906 - val_accuracy: 0.7089 - val_loss: 0.6797 - learning_rate: 2.0000e-05
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7660 - loss: 0.5703 - val_accuracy: 0.7044 - val_loss: 0.6759 - learning_rate: 2.0000e-05
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7747 - loss: 0.5539 - val_accuracy: 0.7057 - val_loss: 0.6708 - learning_rate: 4.0000e-06
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7793 - loss: 0.5364 - val_accuracy: 0.7019 - val_loss: 0.6762 - learning_rate: 4.0000e-06
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7737 - loss: 0.5358 - val_accuracy: 0.7070 - val_loss: 0.6661 - learning_rate: 4.0000e-06
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7853 - loss: 0.5291 - val_accuracy: 0.7057 - val_loss: 0.6674 - learning_rate: 4.0000e-06
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7814 - loss: 0.5280 - val_accuracy: 0.7063 - val_loss: 0.6685 - learning_rate: 4.0000e-06
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.7836 - loss: 0.5160 - val_accuracy: 0.7063 - val_loss: 0.6703 - learning_rate: 8.0000e-07
# Fold 4 - Loss: 0.6660864353179932 - Accuracy: 70.70%
#
# Training Fold 5...
# Class weights (Fold 5): {'0': np.float64(0.587593984962406), '1': np.float64(1.2759183673469388), '2': np.float64(0.8780898876404495), '3': np.float64(1.7415041782729805), '4': np.float64(1.2479041916167664)}
# Found 6252 validated image filenames belonging to 5 classes.
# Found 1562 validated image filenames belonging to 5 classes.
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 99s 234ms/step - accuracy: 0.3464 - loss: 1.5499 - val_accuracy: 0.5218 - val_loss: 1.1117 - learning_rate: 1.0000e-04
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.5263 - loss: 1.1068 - val_accuracy: 0.4955 - val_loss: 1.3591 - learning_rate: 1.0000e-04
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.5853 - loss: 0.9704 - val_accuracy: 0.6204 - val_loss: 0.8921 - learning_rate: 1.0000e-04
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 185ms/step - accuracy: 0.6244 - loss: 0.9024 - val_accuracy: 0.6594 - val_loss: 0.7938 - learning_rate: 1.0000e-04
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6535 - loss: 0.8438 - val_accuracy: 0.5960 - val_loss: 0.9512 - learning_rate: 1.0000e-04
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6721 - loss: 0.7825 - val_accuracy: 0.6767 - val_loss: 0.7769 - learning_rate: 1.0000e-04
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.6787 - loss: 0.7834 - val_accuracy: 0.6748 - val_loss: 0.7781 - learning_rate: 1.0000e-04
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 82s 185ms/step - accuracy: 0.6922 - loss: 0.7618 - val_accuracy: 0.6780 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7171 - loss: 0.6909 - val_accuracy: 0.7279 - val_loss: 0.6762 - learning_rate: 2.0000e-05
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7310 - loss: 0.6477 - val_accuracy: 0.7228 - val_loss: 0.6766 - learning_rate: 2.0000e-05
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7438 - loss: 0.6351 - val_accuracy: 0.7202 - val_loss: 0.6601 - learning_rate: 2.0000e-05
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7412 - loss: 0.6244 - val_accuracy: 0.7113 - val_loss: 0.7197 - learning_rate: 2.0000e-05
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 83s 185ms/step - accuracy: 0.7442 - loss: 0.6093 - val_accuracy: 0.7170 - val_loss: 0.6677 - learning_rate: 2.0000e-05
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 184ms/step - accuracy: 0.7556 - loss: 0.5956 - val_accuracy: 0.7196 - val_loss: 0.6793 - learning_rate: 4.0000e-06
# Fold 5 - Loss: 0.6601289510726929 - Accuracy: 72.02%
# =================================
# Average accuracy over 5 folds: 71.78% (+/- 0.72)
# =================================

# %%
for i, history in enumerate(histories, start=1):
    plt.figure(figsize=(12, 5))

    # Plot Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'Fold {i} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title(f'Fold {i} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.suptitle(f'Performance for Fold {i}', fontsize=16)
    plt.tight_layout()
    plt.show()  # tampilkan plot fold i

print("Semua plot selesai!")
# Out:
# Semua plot selesai!

# %%
y_true = []
y_pred = []
class_labels = list(test_gen.class_indices.keys())

for _ in range(len(test_gen)):
    x_batch, y_batch = next(test_gen)
    y_true.extend(np.argmax(y_batch, axis=1))  # Label asli
    y_pred.extend(np.argmax(model.predict(x_batch), axis=1))  # Prediksi model

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred, target_names=class_labels))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78      1140
#            1       0.30      0.15      0.20       525
#            2       0.67      0.64      0.65       767
#            3       0.79      0.80      0.79       384
#            4       0.97      0.96      0.97       533
#
#     accuracy                           0.71      3349
#    macro avg       0.69      0.69      0.68      3349
# weighted avg       0.68      0.71      0.69      3349

# %%
model.save('/content/drive/MyDrive/my_model_70_30_16.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
